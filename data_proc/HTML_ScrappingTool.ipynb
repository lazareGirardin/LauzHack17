# %%
import pandas as pd
import numpy as np

# %%
#load list of all circuits and years with races from wikipedia
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_World_Heritage_Sites_by_country', header=0)[0].drop(['Natural sites', 'Cultural sites', 'Mixed sites', 'UNESCO region'], axis=1)

# %%
df
# Out:
#                         Country Total sites
# 0                   Afghanistan           2
# 1                       Albania           3
# 2                       Algeria           7
# 3                       Andorra           1
# 4           Antigua and Barbuda           1
# 5                     Argentina          11
# 6                       Armenia           3
# 7                     Australia          19
# 8                       Austria          10
# 9                    Azerbaijan           2
# 10                      Bahrain           2
# 11                   Bangladesh           3
# 12                     Barbados           1
# 13                      Belarus           4
# 14                      Belgium          13
# 15                       Belize           1
# 16                        Benin           2
# 17                      Bolivia           7
# 18       Bosnia and Herzegovina           3
# 19                     Botswana           2
# ...
